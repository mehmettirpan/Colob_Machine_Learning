# %% [markdown]
# <a href="https://colab.research.google.com/github/mehmettirpan/Colab_Machine_Learning/blob/main/stock_market_forecasting_aapl_not_use_validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Apple Stock Market Forecasting**

# %% [markdown]
# # Adımlar
#
# ### Veri toplama temizleme ve işleme adımları;
# * Bu adımları tek seferde yaptık çünkü veriyi ben kednim hazırlayıp imort ettim yahoofinace' dan. Bu yüzden eksik ya da yanlış bir veri yok çünkü verinin kaynağı ben olduğum için yüklemeden önce test etmiştim

# %%
import pandas as pd  #dosyadan verileri(DataFrame) almak için lazım
df = pd.read_csv('/content/AAPL.csv') # AAPL dosyasının konumunu girerek bulunduğu konumdan verilerini çekktik daha doğrusu okuduk
df #df'i yazdırdık
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# 0      1980-12-12    0.128348    0.128906    0.128348    0.128348    0.099450
# 1      1980-12-15    0.122210    0.122210    0.121652    0.121652    0.094261
# 2      1980-12-16    0.113281    0.113281    0.112723    0.112723    0.087343
# 3      1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089504
# 4      1980-12-18    0.118862    0.119420    0.118862    0.118862    0.092099
# ...           ...         ...         ...         ...         ...         ...
# 10802  2023-10-18  175.580002  177.580002  175.110001  175.839996  175.839996
# 10803  2023-10-19  176.039993  177.839996  175.190002  175.460007  175.460007
# 10804  2023-10-20  175.309998  175.419998  172.639999  172.880005  172.880005
# 10805  2023-10-23  170.910004  174.009995  169.929993  173.000000  173.000000
# 10806  2023-10-24  173.050003  173.669998  171.449997  173.440002  173.440002
#
#           Volume
# 0      469033600
# 1      175884800
# 2      105728000
# 3       86441600
# 4       73449600
# ...          ...
# 10802   54764400
# 10803   59302900
# 10804   64189300
# 10805   55980100
# 10806   43764100
#
# [10807 rows x 7 columns]

# %% [markdown]
# * Boş değer Kontolü

# %%
df.isnull().sum() # Bizim verimizde null değer oluğ olmadığını kontrol ettik
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# * Bizim için gerekli olan veri tablosunu aldık kullanmayacağımız veriyi tablodan çıkarttık

# %%
df = df[['Date', 'Close']]
#DataFrame in zaman ve kapanış değerlerine odaklanacak şekilde tabloyu ayarladık
df
# Out:
#              Date       Close
# 0      1980-12-12    0.128348
# 1      1980-12-15    0.121652
# 2      1980-12-16    0.112723
# 3      1980-12-17    0.115513
# 4      1980-12-18    0.118862
# ...           ...         ...
# 10802  2023-10-18  175.839996
# 10803  2023-10-19  175.460007
# 10804  2023-10-20  172.880005
# 10805  2023-10-23  173.000000
# 10806  2023-10-24  173.440002
#
# [10807 rows x 2 columns]

# %%
df['Date'] #DataFrame in zaman kısmı için olan bölümünün çıktısını aldık
# Out:
# 0        1980-12-12
# 1        1980-12-15
# 2        1980-12-16
# 3        1980-12-17
# 4        1980-12-18
#             ...
# 10802    2023-10-18
# 10803    2023-10-19
# 10804    2023-10-20
# 10805    2023-10-23
# 10806    2023-10-24
# Name: Date, Length: 10807, dtype: object

# %% [markdown]
# * İlerleyen adımlarda zaman verisini kullanacağımız için zamanı ayırıp işleyebileceğimiz bir formata çevirdik. Yani string olarak olan formatı tarih formatına dönüştürdük

# %%
import datetime

# Tarih dizisini datetime nesnesine dönüştüren işlev
def str_to_datetime(s):
    split = s.split('-')  # Tarih dizisini parçalara ayırır
    year, month, day = int(split[0]), int(split[1]), int(split[2])  # Yıl, ay ve gün bilgilerini ayırır
    #split[0] sıfırıncı yani ilk değeri dönderecek olupn yanına tire (-) işareti koyuyor
    return datetime.datetime(year=year, month=month, day=day)  # datetime nesnesi oluşturup döndürür

# Örnek kullanım
datetime_object = str_to_datetime('1980-12-12')  # '1980-12-12' tarih dizisini datetime nesnesine dönüştürür
datetime_object
# Out:
# datetime.datetime(1980, 12, 12, 0, 0)

# %%
df # Tekrardan çıktı alıp sağlamasını yapıyoruz
# Out:
#              Date       Close
# 0      1980-12-12    0.128348
# 1      1980-12-15    0.121652
# 2      1980-12-16    0.112723
# 3      1980-12-17    0.115513
# 4      1980-12-18    0.118862
# ...           ...         ...
# 10802  2023-10-18  175.839996
# 10803  2023-10-19  175.460007
# 10804  2023-10-20  172.880005
# 10805  2023-10-23  173.000000
# 10806  2023-10-24  173.440002
#
# [10807 rows x 2 columns]

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
# yukarıda 'Date' sütununu aldık string değerlerini tarih anlamı taşıyan yani sadece harf olmayan anlamlara dönüştürdük
df['Date']  # çıktısını aldık
# Out:
# <ipython-input-7-d0f4b91f68d1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0       1980-12-12
# 1       1980-12-15
# 2       1980-12-16
# 3       1980-12-17
# 4       1980-12-18
#            ...
# 10802   2023-10-18
# 10803   2023-10-19
# 10804   2023-10-20
# 10805   2023-10-23
# 10806   2023-10-24
# Name: Date, Length: 10807, dtype: datetime64[ns]

# %%
df.index = df.pop('Date') # Daha sonra verilerin analizini yaparken bu değerleri indeksleme amacıyla kullanmak için Date sütununu diziye dönüştürdük
df
# Out:
#                  Close
# Date
# 1980-12-12    0.128348
# 1980-12-15    0.121652
# 1980-12-16    0.112723
# 1980-12-17    0.115513
# 1980-12-18    0.118862
# ...                ...
# 2023-10-18  175.839996
# 2023-10-19  175.460007
# 2023-10-20  172.880005
# 2023-10-23  173.000000
# 2023-10-24  173.440002
#
# [10807 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close']) #burada indeks olarak atadığımız date değerlerine karşılık gelen Close değerlerinden bir çizgi grafiği oluşturduk

# %% [markdown]
# ### Başlangıç tarihi ve bitiş tarihi arasındaki zaman serisini işleyerek belirlediğimiz bir pencere boyutunda DataFrame oluşturan kod parçacığı.
#
# Bu kodun temel amacı, belirli bir başlangıç ve bitiş tarihine sahip bir DataFrame içindeki zaman serisini işlemek ve her pencere için geçmiş verilere dayalı özellikler ve hedef değerler oluşturmaktır. Bu, gelecekteki bir tarihteki hedef değerlerin, geçmişteki belirli bir pencere boyutundaki verilere dayalı olarak tahmin edilmesine olanak tanır.

# %%
import numpy as np
def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
    # Başlangıç ve bitiş tarihlerini datetime nesnelerine dönüştür
    first_date, last_date = pd.to_datetime(first_date_str), pd.to_datetime(last_date_str)
    target_date = first_date

    # Belirtilen tarih aralığındaki tarihleri içeren bir dizi oluştur
    dates = pd.date_range(start=target_date, end=last_date)

    # Özellik (X) ve hedef değer (Y) için boş NumPy dizileri oluştur
    X = np.zeros((len(dates), n))
    Y = np.zeros(len(dates))

    # Her bir tarih için
    for i, target_date in enumerate(dates):
        # Belirtilen tarih kadar olan veri alt kümesini al
        df_subset = dataframe.loc[:target_date].tail(n + 1)

        # Hata kontrolü: Alt küme boyutu n+1'e eşit değilse hata mesajı ver
        if len(df_subset) != n + 1:
            print(f'Error: Window of size {n} is too large for date {target_date}')
            return

        # 'Close' sütunundaki değerleri numpy dizisine dönüştür
        values = df_subset['Close'].to_numpy()

        # Özellik matrisine (X) ve hedef değer dizisine (Y) değerleri ata
        X[i, :] = values[:-1]
        Y[i] = values[-1]

    # Oluşturulan veri setini DataFrame'e dönüştür
    ret_df = pd.DataFrame({'Target Date': dates})
    for i in range(n):
        ret_df[f'Target-{n-i}'] = X[:, i]
    ret_df['Target'] = Y

    # DataFrame'i döndür
    return ret_df

# Örnek kullanım
windowed_df = df_to_windowed_df(df, '2019-03-23', '2023-03-23', n=3)
print(windowed_df)
# Out:
#      Target Date    Target-3    Target-2    Target-1      Target
# 0     2019-03-23   46.632500   47.040001   48.772499   47.762501
# 1     2019-03-24   46.632500   47.040001   48.772499   47.762501
# 2     2019-03-25   47.040001   48.772499   47.762501   47.185001
# 3     2019-03-26   48.772499   47.762501   47.185001   46.697498
# 4     2019-03-27   47.762501   47.185001   46.697498   47.117500
# ...          ...         ...         ...         ...         ...
# 1457  2023-03-19  152.589996  152.990005  155.850006  155.000000
# 1458  2023-03-20  152.990005  155.850006  155.000000  157.399994
# 1459  2023-03-21  155.850006  155.000000  157.399994  159.279999
# 1460  2023-03-22  155.000000  157.399994  159.279999  157.830002
# 1461  2023-03-23  157.399994  159.279999  157.830002  158.929993
#
# [1462 rows x 5 columns]

# %% [markdown]
# ## Bu fonksiyon, yukarıda oluşturduğumuz DataFrame'i tarih, girdi ve hedef veri setlerine ayırır ve boyutlarını döndürür.

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  # DataFrame'ı Numpy dizisine dönüştür
  df_as_np = windowed_dataframe.to_numpy()

  # Tarihleri al
  dates = df_as_np[:, 0]

  # Girdi matrisini oluştur
  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  # Hedef sütununu al
  Y = df_as_np[:, -1]

  # Tarihleri, girdileri (X) ve hedefleri (Y) döndür
  return dates, X.astype(np.float32), Y.astype(np.float32)

# Verilen pencere boyutundaki DataFrame'i tarih, girdi ve hedef veri setlerine ayır ve boyutlarını döndür
dates, X, y = windowed_df_to_date_X_y(windowed_df)

# Tarihlerin, girdilerin ve hedeflerin boyutlarını göster
dates.shape, X.shape, y.shape
# Out:
# ((1462,), (1462, 3, 1), (1462,))

# %% [markdown]
# ### Bu kod parçası, veri setini eğitim, doğrulama ve test setlerine bölmek için indeksleri belirler ve her bir veri setini oluşturur.

# %%
# Veri setini eğitim, doğrulama ve test setlerine bölmek için indeksleri belirle
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

# Eğitim veri setini oluştur
dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

# Test veri setini oluştur
dates_test, X_test, y_test = dates[q_80:], X[q_80:], y[q_80:]

# Her bir veri setinin hedef değerlerini tarihlerine bağlı olarak çizdir
plt.plot(dates_train, y_train)
plt.plot(dates_test, y_test)

# Çizimlerin neyi temsil ettiğini belirle
plt.legend(['Train', 'Test'])

# %% [markdown]
# ###Bu kısım, tensorflow.keras kütüphanesi kullanılarak bir LSTM modeli oluşturur, derler ve eğitir.

# %%
from tensorflow.keras.models import Sequential #Sequential sınıfı, bir modelin sıralı bir şekilde birbirine bağlı katmanlardan oluşmasını sağlar.
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

# Model oluşturma ve tanımlama
model = Sequential([layers.Input((3, 1)),  # Giriş katmanı boyutunu belirt (3, 1)
                    layers.LSTM(64),  # 64 hücreye sahip bir LSTM katmanı ekle
                    layers.Dense(32, activation='relu'),  # 32 nöronlu, ReLU aktivasyonlu bir yoğun katman ekle
                    layers.Dense(32, activation='relu'),  # 32 nöronlu, ReLU aktivasyonlu bir yoğun katman daha ekle
                    layers.Dense(1)])  # 1 nöronlu çıkış katmanı ekle

# Modelin derlenmesi
model.compile(loss='mse',  # Kayıp fonksiyonu olarak ortalama karesel hata (MSE) kullan
              optimizer=Adam(learning_rate=0.001),  # Optimizasyon için Adam optimize edici kullan ve öğrenme hızını 0.001 olarak belirle
              metrics=['mean_absolute_error'])  # İzlenecek metrik olarak ortalama mutlak hata (MAE) seç

# Modelin eğitilmesi
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100)  # Modeli eğitmek için eğitim ve doğrulama veri setlerini kullan, 100 epoch boyunca eğitim yap
# Out:
# Epoch 1/100
# 37/37 [==============================] - 5s 21ms/step - loss: 13183.2412 - mean_absolute_error: 107.0456 - val_loss: 20783.2461 - val_mean_absolute_error: 143.7803
# Epoch 2/100
# 37/37 [==============================] - 0s 6ms/step - loss: 11330.1797 - mean_absolute_error: 97.7398 - val_loss: 15593.3467 - val_mean_absolute_error: 124.4231
# Epoch 3/100
# 37/37 [==============================] - 0s 5ms/step - loss: 5667.9194 - mean_absolute_error: 62.5568 - val_loss: 4008.5247 - val_mean_absolute_error: 62.4074
# Epoch 4/100
# 37/37 [==============================] - 0s 5ms/step - loss: 1630.7607 - mean_absolute_error: 35.7857 - val_loss: 1118.7054 - val_mean_absolute_error: 32.0628
# Epoch 5/100
# 37/37 [==============================] - 0s 5ms/step - loss: 491.5968 - mean_absolute_error: 16.8466 - val_loss: 92.4505 - val_mean_absolute_error: 7.3811
# Epoch 6/100
# 37/37 [==============================] - 0s 6ms/step - loss: 42.1146 - mean_absolute_error: 3.7462 - val_loss: 24.0697 - val_mean_absolute_error: 3.9864
# Epoch 7/100
# 37/37 [==============================] - 0s 7ms/step - loss: 13.6912 - mean_absolute_error: 2.5257 - val_loss: 17.3128 - val_mean_absolute_error: 3.3221
# Epoch 8/100
# 37/37 [==============================] - 0s 6ms/step - loss: 8.6983 - mean_absolute_error: 2.0171 - val_loss: 11.8258 - val_mean_absolute_error: 2.7179
# Epoch 9/100
# 37/37 [==============================] - 0s 7ms/step - loss: 7.1083 - mean_absolute_error: 1.8593 - val_loss: 11.7129 - val_mean_absolute_error: 2.7571
# Epoch 10/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.7259 - mean_absolute_error: 1.7958 - val_loss: 15.3034 - val_mean_absolute_error: 3.1116
# Epoch 11/100
# 37/37 [==============================] - 0s 7ms/step - loss: 7.0513 - mean_absolute_error: 1.8851 - val_loss: 14.8898 - val_mean_absolute_error: 3.0578
# Epoch 12/100
# 37/37 [==============================] - 0s 6ms/step - loss: 7.2320 - mean_absolute_error: 1.9288 - val_loss: 14.0148 - val_mean_absolute_error: 2.9575
# Epoch 13/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.9113 - mean_absolute_error: 1.8843 - val_loss: 11.0131 - val_mean_absolute_error: 2.6647
# Epoch 14/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.8695 - mean_absolute_error: 1.8729 - val_loss: 10.7238 - val_mean_absolute_error: 2.6104
# Epoch 15/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.9956 - mean_absolute_error: 1.9144 - val_loss: 10.9247 - val_mean_absolute_error: 2.6571
# Epoch 16/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.2455 - mean_absolute_error: 1.7357 - val_loss: 12.0278 - val_mean_absolute_error: 2.7248
# Epoch 17/100
# 37/37 [==============================] - 0s 5ms/step - loss: 6.7819 - mean_absolute_error: 1.8807 - val_loss: 12.6128 - val_mean_absolute_error: 2.8012
# Epoch 18/100
# 37/37 [==============================] - 0s 7ms/step - loss: 8.0421 - mean_absolute_error: 2.0770 - val_loss: 11.0443 - val_mean_absolute_error: 2.5702
# Epoch 19/100
# 37/37 [==============================] - 0s 6ms/step - loss: 7.6427 - mean_absolute_error: 2.0335 - val_loss: 11.9168 - val_mean_absolute_error: 2.7389
# Epoch 20/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.6139 - mean_absolute_error: 1.8620 - val_loss: 9.9029 - val_mean_absolute_error: 2.4519
# Epoch 21/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.9629 - mean_absolute_error: 1.9091 - val_loss: 14.0086 - val_mean_absolute_error: 2.9696
# Epoch 22/100
# 37/37 [==============================] - 0s 6ms/step - loss: 7.0025 - mean_absolute_error: 1.9227 - val_loss: 10.8574 - val_mean_absolute_error: 2.6222
# Epoch 23/100
# 37/37 [==============================] - 0s 7ms/step - loss: 6.4751 - mean_absolute_error: 1.8320 - val_loss: 10.7382 - val_mean_absolute_error: 2.5862
# Epoch 24/100
# 37/37 [==============================] - 0s 8ms/step - loss: 6.1451 - mean_absolute_error: 1.7768 - val_loss: 10.3686 - val_mean_absolute_error: 2.5326
# Epoch 25/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.3986 - mean_absolute_error: 1.7821 - val_loss: 11.6341 - val_mean_absolute_error: 2.7052
# Epoch 26/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.4906 - mean_absolute_error: 1.8370 - val_loss: 15.8824 - val_mean_absolute_error: 3.1667
# Epoch 27/100
# 37/37 [==============================] - 0s 9ms/step - loss: 6.9608 - mean_absolute_error: 1.8808 - val_loss: 10.9437 - val_mean_absolute_error: 2.5997
# Epoch 28/100
# 37/37 [==============================] - 0s 10ms/step - loss: 6.9256 - mean_absolute_error: 1.9085 - val_loss: 9.6454 - val_mean_absolute_error: 2.3974
# Epoch 29/100
# 37/37 [==============================] - 0s 9ms/step - loss: 6.0532 - mean_absolute_error: 1.7232 - val_loss: 10.5200 - val_mean_absolute_error: 2.5351
# Epoch 30/100
# 37/37 [==============================] - 0s 10ms/step - loss: 6.1659 - mean_absolute_error: 1.7572 - val_loss: 11.0146 - val_mean_absolute_error: 2.6398
# Epoch 31/100
# 37/37 [==============================] - 0s 10ms/step - loss: 7.0154 - mean_absolute_error: 1.9371 - val_loss: 12.5637 - val_mean_absolute_error: 2.7859
# Epoch 32/100
# 37/37 [==============================] - 0s 9ms/step - loss: 6.8354 - mean_absolute_error: 1.9063 - val_loss: 12.2661 - val_mean_absolute_error: 2.8010
# Epoch 33/100
# 37/37 [==============================] - 0s 11ms/step - loss: 6.4348 - mean_absolute_error: 1.8077 - val_loss: 9.9047 - val_mean_absolute_error: 2.4473
# Epoch 34/100
# 37/37 [==============================] - 0s 10ms/step - loss: 6.2350 - mean_absolute_error: 1.8022 - val_loss: 11.2541 - val_mean_absolute_error: 2.6270
# Epoch 35/100
# 37/37 [==============================] - 0s 10ms/step - loss: 6.4443 - mean_absolute_error: 1.8640 - val_loss: 15.2930 - val_mean_absolute_error: 3.0843
# Epoch 36/100
# 37/37 [==============================] - 0s 8ms/step - loss: 6.9386 - mean_absolute_error: 1.8951 - val_loss: 13.8408 - val_mean_absolute_error: 2.9615
# Epoch 37/100
# 37/37 [==============================] - 0s 7ms/step - loss: 6.3396 - mean_absolute_error: 1.8088 - val_loss: 11.4624 - val_mean_absolute_error: 2.6450
# Epoch 38/100
# 37/37 [==============================] - 0s 5ms/step - loss: 6.8103 - mean_absolute_error: 1.8883 - val_loss: 12.7808 - val_mean_absolute_error: 2.8492
# Epoch 39/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.4442 - mean_absolute_error: 1.8101 - val_loss: 10.2063 - val_mean_absolute_error: 2.5018
# Epoch 40/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.2117 - mean_absolute_error: 1.7792 - val_loss: 10.1581 - val_mean_absolute_error: 2.4775
# Epoch 41/100
# 37/37 [==============================] - 0s 5ms/step - loss: 5.9828 - mean_absolute_error: 1.7205 - val_loss: 10.2592 - val_mean_absolute_error: 2.4936
# Epoch 42/100
# 37/37 [==============================] - 0s 5ms/step - loss: 6.1494 - mean_absolute_error: 1.7594 - val_loss: 11.6465 - val_mean_absolute_error: 2.6516
# Epoch 43/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.3639 - mean_absolute_error: 1.7949 - val_loss: 10.5612 - val_mean_absolute_error: 2.4960
# Epoch 44/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.3605 - mean_absolute_error: 1.8140 - val_loss: 11.3473 - val_mean_absolute_error: 2.6293
# Epoch 45/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.3746 - mean_absolute_error: 1.8007 - val_loss: 10.8073 - val_mean_absolute_error: 2.5755
# Epoch 46/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.0032 - mean_absolute_error: 1.7231 - val_loss: 13.2491 - val_mean_absolute_error: 2.8821
# Epoch 47/100
# 37/37 [==============================] - 0s 6ms/step - loss: 8.3005 - mean_absolute_error: 2.0990 - val_loss: 10.5514 - val_mean_absolute_error: 2.5103
# Epoch 48/100
# 37/37 [==============================] - 0s 5ms/step - loss: 9.1074 - mean_absolute_error: 2.2625 - val_loss: 17.1710 - val_mean_absolute_error: 3.2931
# Epoch 49/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.3258 - mean_absolute_error: 1.7926 - val_loss: 9.8058 - val_mean_absolute_error: 2.4208
# Epoch 50/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.3199 - mean_absolute_error: 1.7768 - val_loss: 10.2848 - val_mean_absolute_error: 2.5082
# Epoch 51/100
# 37/37 [==============================] - 0s 6ms/step - loss: 5.7753 - mean_absolute_error: 1.7038 - val_loss: 10.3284 - val_mean_absolute_error: 2.4605
# Epoch 52/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.4458 - mean_absolute_error: 1.8210 - val_loss: 12.5102 - val_mean_absolute_error: 2.7716
# Epoch 53/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.0778 - mean_absolute_error: 1.7785 - val_loss: 11.0458 - val_mean_absolute_error: 2.5882
# Epoch 54/100
# 37/37 [==============================] - 0s 7ms/step - loss: 6.8119 - mean_absolute_error: 1.8876 - val_loss: 19.2082 - val_mean_absolute_error: 3.6128
# Epoch 55/100
# 37/37 [==============================] - 0s 5ms/step - loss: 7.5303 - mean_absolute_error: 2.0283 - val_loss: 9.8057 - val_mean_absolute_error: 2.4161
# Epoch 56/100
# 37/37 [==============================] - 0s 6ms/step - loss: 7.4224 - mean_absolute_error: 2.0121 - val_loss: 14.7828 - val_mean_absolute_error: 3.0544
# Epoch 57/100
# 37/37 [==============================] - 0s 5ms/step - loss: 7.2751 - mean_absolute_error: 1.9458 - val_loss: 11.5633 - val_mean_absolute_error: 2.6377
# Epoch 58/100
# 37/37 [==============================] - 0s 6ms/step - loss: 7.0402 - mean_absolute_error: 1.9375 - val_loss: 15.9127 - val_mean_absolute_error: 3.1737
# Epoch 59/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.2692 - mean_absolute_error: 1.7972 - val_loss: 11.2258 - val_mean_absolute_error: 2.5999
# Epoch 60/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.0220 - mean_absolute_error: 1.7457 - val_loss: 11.3278 - val_mean_absolute_error: 2.6181
# Epoch 61/100
# 37/37 [==============================] - 0s 7ms/step - loss: 6.4297 - mean_absolute_error: 1.7970 - val_loss: 10.9030 - val_mean_absolute_error: 2.5508
# Epoch 62/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.1414 - mean_absolute_error: 1.7634 - val_loss: 11.2507 - val_mean_absolute_error: 2.6322
# Epoch 63/100
# 37/37 [==============================] - 0s 6ms/step - loss: 5.9722 - mean_absolute_error: 1.7300 - val_loss: 9.6937 - val_mean_absolute_error: 2.3916
# Epoch 64/100
# 37/37 [==============================] - 0s 7ms/step - loss: 6.1076 - mean_absolute_error: 1.7762 - val_loss: 9.7286 - val_mean_absolute_error: 2.3857
# Epoch 65/100
# 37/37 [==============================] - 0s 5ms/step - loss: 5.7117 - mean_absolute_error: 1.6828 - val_loss: 10.1722 - val_mean_absolute_error: 2.4673
# Epoch 66/100
# 37/37 [==============================] - 0s 7ms/step - loss: 6.2393 - mean_absolute_error: 1.7869 - val_loss: 10.4963 - val_mean_absolute_error: 2.4740
# Epoch 67/100
# 37/37 [==============================] - 0s 7ms/step - loss: 6.2661 - mean_absolute_error: 1.7911 - val_loss: 11.0190 - val_mean_absolute_error: 2.5639
# Epoch 68/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.2802 - mean_absolute_error: 1.8026 - val_loss: 11.7580 - val_mean_absolute_error: 2.6862
# Epoch 69/100
# 37/37 [==============================] - 0s 5ms/step - loss: 6.1306 - mean_absolute_error: 1.7752 - val_loss: 10.6783 - val_mean_absolute_error: 2.5566
# Epoch 70/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.0684 - mean_absolute_error: 1.7451 - val_loss: 9.8465 - val_mean_absolute_error: 2.4238
# Epoch 71/100
# 37/37 [==============================] - 0s 7ms/step - loss: 5.8735 - mean_absolute_error: 1.7202 - val_loss: 11.0069 - val_mean_absolute_error: 2.5911
# Epoch 72/100
# 37/37 [==============================] - 0s 7ms/step - loss: 6.0726 - mean_absolute_error: 1.7863 - val_loss: 9.8533 - val_mean_absolute_error: 2.3905
# Epoch 73/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.1802 - mean_absolute_error: 1.8319 - val_loss: 9.8362 - val_mean_absolute_error: 2.4158
# Epoch 74/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.2665 - mean_absolute_error: 1.7734 - val_loss: 13.0300 - val_mean_absolute_error: 2.8279
# Epoch 75/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.2498 - mean_absolute_error: 1.7938 - val_loss: 9.7184 - val_mean_absolute_error: 2.3946
# Epoch 76/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.0039 - mean_absolute_error: 1.7376 - val_loss: 10.6789 - val_mean_absolute_error: 2.5471
# Epoch 77/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.2202 - mean_absolute_error: 1.8279 - val_loss: 12.1016 - val_mean_absolute_error: 2.7358
# Epoch 78/100
# 37/37 [==============================] - 0s 6ms/step - loss: 8.4589 - mean_absolute_error: 2.1899 - val_loss: 13.1018 - val_mean_absolute_error: 2.8413
# Epoch 79/100
# 37/37 [==============================] - 0s 8ms/step - loss: 6.9474 - mean_absolute_error: 1.9199 - val_loss: 11.2362 - val_mean_absolute_error: 2.6494
# Epoch 80/100
# 37/37 [==============================] - 0s 10ms/step - loss: 6.0349 - mean_absolute_error: 1.7503 - val_loss: 9.8487 - val_mean_absolute_error: 2.4052
# Epoch 81/100
# 37/37 [==============================] - 0s 9ms/step - loss: 5.6993 - mean_absolute_error: 1.6816 - val_loss: 12.7767 - val_mean_absolute_error: 2.7973
# Epoch 82/100
# 37/37 [==============================] - 0s 9ms/step - loss: 6.4158 - mean_absolute_error: 1.8239 - val_loss: 9.8306 - val_mean_absolute_error: 2.3935
# Epoch 83/100
# 37/37 [==============================] - 0s 9ms/step - loss: 6.5919 - mean_absolute_error: 1.8640 - val_loss: 10.5354 - val_mean_absolute_error: 2.5239
# Epoch 84/100
# 37/37 [==============================] - 0s 8ms/step - loss: 5.9562 - mean_absolute_error: 1.7143 - val_loss: 9.9380 - val_mean_absolute_error: 2.4365
# Epoch 85/100
# 37/37 [==============================] - 0s 9ms/step - loss: 6.3125 - mean_absolute_error: 1.8269 - val_loss: 10.4645 - val_mean_absolute_error: 2.5117
# Epoch 86/100
# 37/37 [==============================] - 0s 11ms/step - loss: 6.2240 - mean_absolute_error: 1.7976 - val_loss: 9.9485 - val_mean_absolute_error: 2.4193
# Epoch 87/100
# 37/37 [==============================] - 0s 10ms/step - loss: 6.3177 - mean_absolute_error: 1.8136 - val_loss: 15.8153 - val_mean_absolute_error: 3.1904
# Epoch 88/100
# 37/37 [==============================] - 0s 11ms/step - loss: 6.6852 - mean_absolute_error: 1.8816 - val_loss: 10.1793 - val_mean_absolute_error: 2.4781
# Epoch 89/100
# 37/37 [==============================] - 0s 9ms/step - loss: 6.2999 - mean_absolute_error: 1.8228 - val_loss: 9.8232 - val_mean_absolute_error: 2.4121
# Epoch 90/100
# 37/37 [==============================] - 0s 7ms/step - loss: 6.4508 - mean_absolute_error: 1.8891 - val_loss: 10.0113 - val_mean_absolute_error: 2.4517
# Epoch 91/100
# 37/37 [==============================] - 0s 6ms/step - loss: 5.7838 - mean_absolute_error: 1.7118 - val_loss: 10.0235 - val_mean_absolute_error: 2.4419
# Epoch 92/100
# 37/37 [==============================] - 0s 7ms/step - loss: 6.8254 - mean_absolute_error: 1.8650 - val_loss: 15.9925 - val_mean_absolute_error: 3.2360
# Epoch 93/100
# 37/37 [==============================] - 0s 8ms/step - loss: 6.4214 - mean_absolute_error: 1.8197 - val_loss: 11.4861 - val_mean_absolute_error: 2.6214
# Epoch 94/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.0515 - mean_absolute_error: 1.7551 - val_loss: 16.2064 - val_mean_absolute_error: 3.2281
# Epoch 95/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.5736 - mean_absolute_error: 1.8638 - val_loss: 13.3478 - val_mean_absolute_error: 2.8730
# Epoch 96/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.7139 - mean_absolute_error: 1.8730 - val_loss: 15.0850 - val_mean_absolute_error: 3.0663
# Epoch 97/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.7300 - mean_absolute_error: 1.8793 - val_loss: 10.7542 - val_mean_absolute_error: 2.5335
# Epoch 98/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.8227 - mean_absolute_error: 1.8892 - val_loss: 9.9085 - val_mean_absolute_error: 2.4264
# Epoch 99/100
# 37/37 [==============================] - 0s 6ms/step - loss: 5.9472 - mean_absolute_error: 1.7304 - val_loss: 10.1404 - val_mean_absolute_error: 2.4565
# Epoch 100/100
# 37/37 [==============================] - 0s 6ms/step - loss: 6.1542 - mean_absolute_error: 1.7602 - val_loss: 10.6946 - val_mean_absolute_error: 2.5573

# %% [markdown]
# Bu kod, eğitim veri seti üzerindeki tahminlerin ve gerçek gözlemlerin bir çizgi grafiği üzerinde gösterilmesini sağlar.

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter

# Grafiği oluştur
fig, ax = plt.subplots()

# Model üzerinde eğitim veri seti (X_train) üzerinde tahminleme yap
train_predictions = model.predict(X_train).flatten()

# Eğitim tarihlerine karşılık gelen tahminleri ve gerçek değerleri içeren bir çizgi grafiği oluştur
ax.plot(dates_train, train_predictions, label='Training Predictions')
ax.plot(dates_train, y_train, label='Training Observations')

# X ekseni tarih formatını düzenleme
date_format = DateFormatter("%Y-%m-%d")  # İstediğiniz tarih formatını belirleyin yani şöyle %Y dört haneli yıl formatı, %m 2 haneli ay formatı ve %d 2 haneli olarak gün formatını belirlemiş olur
ax.xaxis.set_major_formatter(date_format)

# X ekseni etiketlerini döndürme
plt.xticks(rotation=35)  # İhtiyaca göre döndürme açısını ayarlayabilirsiniz

# Grafiğe açıklama ekle
plt.legend()

# Grafiği göster
plt.show()
# Out:
# 37/37 [==============================] - 1s 2ms/step

# %% [markdown]
# Bu kod, test veri seti üzerindeki tahminlerin ve gerçek gözlemlerin bir çizgi grafiği üzerinde gösterilmesini sağlar.

# %%
# Grafiği oluştur
fig, ax = plt.subplots()

# Model üzerinde test veri seti (X_test) üzerinde tahminleme yap
test_predictions = model.predict(X_test).flatten()

# Test tarihlerine karşılık gelen tahminleri ve gerçek değerleri içeren bir çizgi grafiği oluştur
ax.plot(dates_test, test_predictions, label='Testing Predictions')
ax.plot(dates_test, y_test, label='Testing Observations')

# X ekseni tarih formatını düzenleme
date_format = DateFormatter("%Y-%m-%d")  # İstediğiniz tarih formatını belirleyin
ax.xaxis.set_major_formatter(date_format)

# X ekseni etiketlerini döndürme
plt.xticks(rotation=35)  # İhtiyaca göre döndürme açısını ayarlayabilirsiniz

# Grafiğe açıklama ekle
plt.legend()

# Grafiği göster
plt.show()
# Out:
# 10/10 [==============================] - 0s 4ms/step

# %% [markdown]
# * Bu kod, farklı veri setleri üzerinde yapılan tahminlerin ve gerçek gözlemlerin görselleştirilmesini sağlar.
#
# * Bu satır, eğitim verileri ile modelin eğittiği ve tahmin yaptığı verileri aynı grafik üzerinde karşılaştırmak için kullanılır. Böylece gerçek verilere modelin ne kadar yakın tahminler yaptığını görmek mümkün olur.

# %%
plt.plot(dates_train, train_predictions) # eğitim veri seti için yapılan tahminleri görselleştirir.
plt.plot(dates_train, y_train) # eğitim veri seti için gerçek gözlemleri görselleştirir.
plt.plot(dates_test, test_predictions) # test veri seti için yapılan tahminleri görselleştirir.
plt.plot(dates_test, y_test) # test veri seti için gerçek gözlemleri görselleştirir.
# X ekseni tarih formatını düzenleme
date_format = DateFormatter("%Y-%m-%d")  # İstediğiniz tarih formatını belirleyin
ax.xaxis.set_major_formatter(date_format)

# X ekseni etiketlerini döndürme
plt.xticks(rotation=35)  # İhtiyaca göre döndürme açısını ayarlayabilirsiniz

plt.legend(['Training Predictions',
            'Training Observations',
            'Testing Predictions',
            'Testing Observations'])

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test, test_predictions)
print("Test Accuracy rate: %", r2 * 100)
# Out:
# Test Accuracy rate: % 90.30153746682569
